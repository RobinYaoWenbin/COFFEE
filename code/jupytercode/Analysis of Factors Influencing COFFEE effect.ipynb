# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
sys.path.append("../lib/")
sys.path.append("../optimization_result_ana/")
sys.path.append("../IBTDM_multi_city/")
sys.path.append("../pol_est_sim/")
from datetime import datetime, timezone, timedelta
from matplotlib import ticker
import cal_factors
import IBTDM_effect_factors
import copy
import utils
import time, datetime
import importlib
importlib.reload(utils)
importlib.reload(cal_factors)
importlib.reload(IBTDM_effect_factors)
# Out:
# <module 'IBTDM_effect_factors' from '../IBTDM_multi_city\\IBTDM_effect_factors.py'>

# %%
#Multicollinearity analysis
IBTDM_effect_factors.relation.cal_VIF(effect_file="../../data/multi_city_DTASCTB_data/new_IBTDM_effect_ana.xlsx")
# Out:
# const         755.407969
# coe_var         8.567075
# max_L         688.025519
# min_L         716.516683
# spatial_cv      6.970315
# dtype: float64

# %%
IBTDM_effect_factors.relation.get(effect_file="../../data/multi_city_DTASCTB_data/new_IBTDM_effect_ana.xlsx",var_name='coe_var')
# Out:
# D:\Software\anaconda\envs\COFFEE\lib\site-packages\statsmodels\stats\stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   "samples were given." % int(n), ValueWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#               effect   coe_var      diff     max_L     min_L  spatial_cv  max_load
# effect      1.000000  0.932086  0.868249 -0.744996 -0.806545    0.225457  0.340254
# coe_var     0.932086  1.000000  0.829567 -0.668255 -0.740689    0.054649  0.339303
# diff        0.868249  0.829567  1.000000 -0.744676 -0.810915    0.060242  0.076324
# max_L      -0.744996 -0.668255 -0.744676  1.000000  0.992095   -0.562648 -0.161924
# min_L      -0.806545 -0.740689 -0.810915  0.992095  1.000000   -0.471747 -0.151478
# spatial_cv  0.225457  0.054649  0.060242 -0.562648 -0.471747    1.000000  0.418561
# ...

# %%
IBTDM_effect_factors.relation.get(effect_file="../../data/multi_city_DTASCTB_data/new_IBTDM_effect_ana.xlsx",var_name='spatial_cv')
# Out:
# D:\Software\anaconda\envs\COFFEE\lib\site-packages\statsmodels\stats\stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   "samples were given." % int(n), ValueWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#               effect   coe_var      diff     max_L     min_L  spatial_cv  max_load
# effect      1.000000  0.932086  0.868249 -0.744996 -0.806545    0.225457  0.340254
# coe_var     0.932086  1.000000  0.829567 -0.668255 -0.740689    0.054649  0.339303
# diff        0.868249  0.829567  1.000000 -0.744676 -0.810915    0.060242  0.076324
# max_L      -0.744996 -0.668255 -0.744676  1.000000  0.992095   -0.562648 -0.161924
# min_L      -0.806545 -0.740689 -0.810915  0.992095  1.000000   -0.471747 -0.151478
# spatial_cv  0.225457  0.054649  0.060242 -0.562648 -0.471747    1.000000  0.418561
# ...

# %%
IBTDM_effect_factors.relation.get(effect_file="../../data/multi_city_DTASCTB_data/new_IBTDM_effect_ana.xlsx",var_name='max_L')
# Out:
# D:\Software\anaconda\envs\COFFEE\lib\site-packages\statsmodels\stats\stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   "samples were given." % int(n), ValueWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#               effect   coe_var      diff     max_L     min_L  spatial_cv  max_load
# effect      1.000000  0.932086  0.868249 -0.744996 -0.806545    0.225457  0.340254
# coe_var     0.932086  1.000000  0.829567 -0.668255 -0.740689    0.054649  0.339303
# diff        0.868249  0.829567  1.000000 -0.744676 -0.810915    0.060242  0.076324
# max_L      -0.744996 -0.668255 -0.744676  1.000000  0.992095   -0.562648 -0.161924
# min_L      -0.806545 -0.740689 -0.810915  0.992095  1.000000   -0.471747 -0.151478
# spatial_cv  0.225457  0.054649  0.060242 -0.562648 -0.471747    1.000000  0.418561
# ...

# %%
IBTDM_effect_factors.relation.get(effect_file="../../data/multi_city_DTASCTB_data/new_IBTDM_effect_ana.xlsx",var_name='max_load')
# Out:
# D:\Software\anaconda\envs\COFFEE\lib\site-packages\statsmodels\stats\stattools.py:75: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   "samples were given." % int(n), ValueWarning)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#               effect   coe_var      diff     max_L     min_L  spatial_cv  max_load
# effect      1.000000  0.932086  0.868249 -0.744996 -0.806545    0.225457  0.340254
# coe_var     0.932086  1.000000  0.829567 -0.668255 -0.740689    0.054649  0.339303
# diff        0.868249  0.829567  1.000000 -0.744676 -0.810915    0.060242  0.076324
# max_L      -0.744996 -0.668255 -0.744676  1.000000  0.992095   -0.562648 -0.161924
# min_L      -0.806545 -0.740689 -0.810915  0.992095  1.000000   -0.471747 -0.151478
# spatial_cv  0.225457  0.054649  0.060242 -0.562648 -0.471747    1.000000  0.418561
# ...
